# %% [markdown]
# # Base de dados do censo
#
# - Fonte: https://archive.ics.uci.edu/ml/datasets/adult

# %% [markdown]
# # Importação das bibliotecas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# # Exploração dos dados

# %%
base_census = pd.read_csv('../datasets/census.csv')

# %%
#visualizando dados
base_census
# Out:
#        age          workclass  final-weight    education  education-num  \
# 0       39          State-gov         77516    Bachelors             13
# 1       50   Self-emp-not-inc         83311    Bachelors             13
# 2       38            Private        215646      HS-grad              9
# 3       53            Private        234721         11th              7
# 4       28            Private        338409    Bachelors             13
# ...    ...                ...           ...          ...            ...
# 32556   27            Private        257302   Assoc-acdm             12
# 32557   40            Private        154374      HS-grad              9
# 32558   58            Private        151910      HS-grad              9
# 32559   22            Private        201490      HS-grad              9
# 32560   52       Self-emp-inc        287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 0         Male          2174             0             40   United-States
# 1         Male             0             0             13   United-States
# 2         Male             0             0             40   United-States
# 3         Male             0             0             40   United-States
# 4       Female             0             0             40            Cuba
# ...        ...           ...           ...            ...             ...
# 32556   Female             0             0             38   United-States
# 32557     Male             0             0             40   United-States
# 32558   Female             0             0             40   United-States
# 32559     Male             0             0             20   United-States
# 32560   Female         15024             0             40   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %%
#vamos obaservar alguns calculos dos atributos numéricos
base_census.describe()
# Out:
#                 age  final-weight  education-num  capital-gain  capital-loos  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hour-per-week
# count   32561.000000
# mean       40.437456
# std        12.347429
# min         1.000000
# 25%        40.000000
# 50%        40.000000
# 75%        45.000000
# max        99.000000

# %%
#verificando se há valores faltantes
base_census.isnull().sum()
# Out:
# age               0
# workclass         0
# final-weight      0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loos      0
# hour-per-week     0
# native-country    0
# income            0
# dtype: int64

# %% [markdown]
# # Visualizaçã dos dados

# %%
#contando quantos registros de cada classe existem
np.unique(base_census['income'], return_counts=True)
# Out:
# (array([' <=50K', ' >50K'], dtype=object), array([24720,  7841]))

# %%
#Exibindo a quantidade por classe num gráfico de contagem
sns.countplot(data=base_census, x='income', hue='income', palette=['blue', 'orange'], legend=False);

# %%
#Visualizando a distribuição de acordo com a idade com um histograma
plt.hist(x=base_census['age'], rwidth=0.9);

# %%
#Gerando histograma de acordo com o education_num(número de anos estudados)
plt.hist(x=base_census['education-num'], rwidth=0.9);

# %%
# histograma considerando o atributo hour-per-week (número de horas trabalhadas por semana)
plt.hist(x=base_census['hour-per-week'], rwidth=0.9);

# %%
#agrupamento de acordo com o número de pessoa por workclass e age
grafico = px.treemap(base_census, path=['workclass','age'])
grafico.show(renderer="browser")

# %%
#distribuição de acordo com o occupation,relationship e age
grafico = px.treemap(base_census, path=['occupation', 'relationship', 'age'])
grafico.show(renderer="browser")

# %%
# gerando grafico de categorias paralelas relacionando occupation com relationship
grafico = px.parallel_categories(base_census, dimensions=['occupation', 'relationship'])
grafico.show(renderer="browser")

# %%
# gerando grafico de categorias paralelas relacionando workclass, occupation e income
grafico = px.parallel_categories(base_census, dimensions=['workclass', 'occupation', 'income'])
grafico.show(renderer="browser")

# %%
# gerando grafico de categorias paralelas relacionando education e income
grafico = px.parallel_categories(base_census, dimensions=['education', 'income'])
grafico.show(renderer="browser")

# %% [markdown]
# # Divisão entre previsores e classe

# %%
base_census.columns
# Out:
# Index(['age', 'workclass', 'final-weight', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loos', 'hour-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
# atributos previsores
X_census = base_census.iloc[:, 0:14].values

# %%
X_census
# Out:
# array([[39, ' State-gov', 77516, ..., 0, 40, ' United-States'],
#        [50, ' Self-emp-not-inc', 83311, ..., 0, 13, ' United-States'],
#        [38, ' Private', 215646, ..., 0, 40, ' United-States'],
#        ...,
#        [58, ' Private', 151910, ..., 0, 40, ' United-States'],
#        [22, ' Private', 201490, ..., 0, 20, ' United-States'],
#        [52, ' Self-emp-inc', 287927, ..., 0, 40, ' United-States']],
#       shape=(32561, 14), dtype=object)

# %%
X_census[0]
# Out:
# array([39, ' State-gov', 77516, ' Bachelors', 13, ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', 2174, 0, 40,
#        ' United-States'], dtype=object)

# %%
# atributo classe
Y_census = base_census.iloc[:, 14].values

# %%
# observando valores
Y_census
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       shape=(32561,), dtype=object)

# %% [markdown]
# # Tratamento dos atributos categóricos

# %% [markdown]
# # LabelEnconder

# %%
# aplicando teste de labelenconder para transformar os atributos categóricos em números
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder_teste = LabelEncoder()

# %%
# convertendo workclass (index 1 ) em números
teste = label_encoder_teste.fit_transform(X_census[:,1])

# %%
# Checando se workclass foi convertido de fato
teste
# Out:
# array([7, 6, 4, ..., 4, 4, 5], shape=(32561,))

# %%
# criando enconders para cada atributo categórico
label_encoder_workclass = LabelEncoder()
label_encoder_education = LabelEncoder()
label_encoder_marital = LabelEncoder()
label_encoder_occupation = LabelEncoder()
label_encoder_relationship = LabelEncoder()
label_encoder_race = LabelEncoder()
label_encoder_sex = LabelEncoder()
label_encoder_country = LabelEncoder()

# %%
# aplicando conversão em cada um dos atributos categóricos
X_census[:,1] = label_encoder_workclass.fit_transform(X_census[:,1])
X_census[:,3] = label_encoder_education.fit_transform(X_census[:,3])
X_census[:,5] = label_encoder_marital.fit_transform(X_census[:,5])
X_census[:,6] = label_encoder_occupation.fit_transform(X_census[:,6])
X_census[:,7] = label_encoder_relationship.fit_transform(X_census[:,7])
X_census[:,8] = label_encoder_race.fit_transform(X_census[:,8])
X_census[:,9] = label_encoder_sex.fit_transform(X_census[:,9])
X_census[:,13] = label_encoder_country.fit_transform(X_census[:,13])

# %%
# visualizando base com apenas atributos numéricos
# como há muito atributos há uma diferença grande no número que os representa
# o algoritmo de ml atribui um peso maior a eles, mas isso nao e interessante pois trata-se apenas de categorias 
X_census
# Out:
# array([[39, 7, 77516, ..., 0, 40, 39],
#        [50, 6, 83311, ..., 0, 13, 39],
#        [38, 4, 215646, ..., 0, 40, 39],
#        ...,
#        [58, 4, 151910, ..., 0, 40, 39],
#        [22, 4, 201490, ..., 0, 20, 39],
#        [52, 5, 287927, ..., 0, 40, 39]], shape=(32561, 14), dtype=object)

# %% [markdown]
# # OneHotEnconder

# %%
# Para resolver o esse problema vamos usar onehotenconder
# Ao invés de ele atribuir uma única coluna para cada categoria numeando da primeira ate a última em ordem
# Ele cria colunas de acordo com o número de categorias

# carro

# labelenconder
# gol pálio uno
#   1     2   3

# onehotencoder
# gol   1 0 0
# pálio 0 1 0
# uno   0 0 1

# %%
# importando bibliotecas para implementação do onehotencoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
onehotencoder_census = ColumnTransformer(transformers=[('OneHot', OneHotEncoder(), [1, 3, 5, 6, 7, 8, 9, 13])], remainder='passthrough') #índices dos atributos a serem transformados

# %%
# efetivando transformação
X_census = onehotencoder_census.fit_transform(X_census).toarray()

# %%
# verificando resultado
X_census
# Out:
# array([[0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 2.1740e+03, 0.0000e+00,
#         4.0000e+01],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         1.3000e+01],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         4.0000e+01],
#        ...,
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         4.0000e+01],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         2.0000e+01],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 1.5024e+04, 0.0000e+00,
#         4.0000e+01]], shape=(32561, 108))

# %%
X_census[0]
# Out:
# array([0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00,
#        0.0000e+00, 0.0000e+00, 3.9000e+01, 7.7516e+04, 1.3000e+01,
#        2.1740e+03, 0.0000e+00, 4.0000e+01])

# %%
X_census.shape
# Out:
# (32561, 108)

# %% [markdown]
# # Escalonamento dos valores

# %%
# aplicar escolanamento para deixar todos os atributos no mesmo formato
from sklearn.preprocessing import StandardScaler
scaler_census = StandardScaler()
X_census = scaler_census.fit_transform(X_census)

# %%
X_census[0]
# Out:
# array([-0.2444502 , -0.17429511, -0.26209736, -0.01466381, -1.5167923 ,
#        -0.18838933, -0.29093568,  4.90769968, -0.02073999, -0.17175325,
#        -0.19348662, -0.11609195, -0.07201601, -0.10164955, -0.1422718 ,
#        -0.12664495, -0.18406376, -0.21053433,  2.25399324, -0.11334387,
#        -0.68994199, -0.23637391, -0.03960742, -0.13419553, -0.53714425,
#        -0.39750806, -0.02658695, -0.92284068, -0.11403678,  1.43105786,
#        -0.1802846 , -0.17735813, -0.24494366,  2.76348874, -0.01662771,
#        -0.37949517, -0.37774555, -0.17745022, -0.20957797, -0.25595432,
#        -0.33554133, -0.06780164, -0.38166338, -0.14260848, -0.35531609,
#        -0.17127887, -0.22710355, -0.82533335,  1.70899099, -0.17624972,
#        -0.42934582, -0.34403232, -0.22492681, -0.09820087, -0.18155194,
#        -0.32576824, -0.09161163,  0.4130197 , -0.70307135,  0.70307135,
#        -0.13502327, -0.02416321, -0.06107342, -0.0480488 , -0.04260602,
#        -0.05409379, -0.04641598, -0.02933708, -0.05714946, -0.05264698,
#        -0.02985682, -0.06500204, -0.02985682, -0.04437806, -0.03678503,
#        -0.00554189, -0.01998525, -0.02479131, -0.01998525, -0.05550333,
#        -0.03636406, -0.02715919, -0.04740236, -0.04993839, -0.04367781,
#        -0.02351838, -0.1419344 , -0.03233087, -0.02073999, -0.03087016,
#        -0.07821827, -0.04296623, -0.03372864, -0.05927412, -0.01920091,
#        -0.0496284 , -0.03960742, -0.02351838, -0.02416321,  0.34095391,
#        -0.04540836, -0.02217266,  0.03067056, -1.06361075,  1.13473876,
#         0.1484529 , -0.21665953, -0.03542945])

# %%
# Divisão da base em teste e treinamento
from sklearn.model_selection import train_test_split

# %%
# separando os atributos previsores e classe em uma porção para treinamento e outra para teste
X_census_treinamento, X_census_teste, Y_census_treinamento, Y_census_teste = train_test_split(X_census, Y_census, test_size = 0.15, random_state = 0)

# %%
# verificando a divisão
X_census_treinamento.shape , Y_census_treinamento.shape
# Out:
# ((27676, 108), (27676,))

# %%
X_census_teste.shape , Y_census_teste.shape
# Out:
# ((4885, 108), (4885,))

# %% [markdown]
# # Salvando as bases

# %%
import pickle

# %%
with open('../datasets/processed/census.pkl', mode='wb') as f:
    pickle.dump([X_census_treinamento, Y_census_treinamento, X_census_teste, Y_census_teste], f)

# %% [markdown]
# # Aplicando algoritmo Naive Bayes

# %%
# Carregando dados processados 
with open('../datasets/processed/census.pkl', 'rb') as f:
    X_census_treinamento, Y_census_treinamento, X_census_teste, Y_census_teste = pickle.load(f)

# %%
# checando se as variáveis foram carregadas
X_census_treinamento.shape, Y_census_treinamento.shape
# Out:
# ((27676, 108), (27676,))

# %%
X_census_teste.shape, Y_census_teste.shape
# Out:
# ((4885, 108), (4885,))

# %%
# crianto algoritmo e aplicando treinamento para geração da tabela de probabilidade
naive_census = GaussianNB()
naive_census.fit(X_census_treinamento, Y_census_treinamento)
# Out:
# GaussianNB()

# %%
# fazendo previsões usando a base de teste
previsoes = naive_census.predict(X_census_teste)

# %%
previsoes
# Out:
# array([' >50K', ' >50K', ' >50K', ..., ' <=50K', ' >50K', ' >50K'],
#       shape=(4885,), dtype='<U6')

# %%
# exibindo as repostas reais
Y_census_teste
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' <=50K'],
#       shape=(4885,), dtype=object)

# %%
# importando métricas
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
# calculando precisão
accuracy_score(Y_census_teste, previsoes)
# Out:
# 0.4767656090071648

# %%
# calculando matriz de confusão
confusion_matrix(Y_census_teste, previsoes)
# Out:
# array([[1172, 2521],
#        [  35, 1157]])

# %%
# usando matriz de confusão do yellowbrick
from yellowbrick.classifier import ConfusionMatrix

# %%
# para ler uma matrix de confusão verificamos a intersecções entre os valores 
cm = ConfusionMatrix(naive_census)
cm.fit(X_census_treinamento, Y_census_treinamento)
cm.score(X_census_teste, Y_census_teste)
# Out:
# 0.4767656090071648

# %%
# Gerando relatório de classificação
print(classification_report(Y_census_teste, previsoes))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.97      0.32      0.48      3693
#         >50K       0.31      0.97      0.48      1192
#
#     accuracy                           0.48      4885
#    macro avg       0.64      0.64      0.48      4885
# weighted avg       0.81      0.48      0.48      4885

# %% [markdown]
# # Aplicando Algoritmo de Árvore de Decisão

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# Carregando dados processados 
with open('../datasets/processed/census.pkl', 'rb') as f:
    X_census_treinamento, Y_census_treinamento, X_census_teste, Y_census_teste = pickle.load(f)

# %%
X_census_treinamento.shape, Y_census_treinamento.shape
# Out:
# ((27676, 108), (27676,))

# %%
X_census_teste.shape, Y_census_teste.shape
# Out:
# ((4885, 108), (4885,))

# %%
# criando a arvore e fazendo treinamento
arvore_census = DecisionTreeClassifier(criterion = 'entropy', random_state=0)
arvore_census.fit(X_census_treinamento, Y_census_treinamento)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
# fazendo previsões
previsoes = arvore_census.predict(X_census_teste)
previsoes
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       shape=(4885,), dtype=object)

# %%
# Exibindo as respostas reais para comparação com a previsão 
Y_census_teste
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' <=50K'],
#       shape=(4885,), dtype=object)

# %%
# Fazendo o calculo de precisão
accuracy_score(Y_census_teste, previsoes)
# Out:
# 0.8104401228249745

# %%
# gerando matriz de confusão
from yellowbrick.classifier import ConfusionMatrix
cm = ConfusionMatrix(arvore_census)
cm.fit(X_census_treinamento, Y_census_treinamento)
cm.score(X_census_teste, Y_census_teste)
# Out:
# 0.8104401228249745

# %%
# gerando relatório de classificação
print(classification_report(Y_census_teste, previsoes))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.88      0.87      0.87      3693
#         >50K       0.61      0.61      0.61      1192
#
#     accuracy                           0.81      4885
#    macro avg       0.74      0.74      0.74      4885
# weighted avg       0.81      0.81      0.81      4885

# %% [markdown]
# # Aplicando random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# carregando dados processados
import pickle
with open('../datasets/processed/census.pkl', 'rb') as f:
    X_census_treinamento, Y_census_treinamento, X_census_teste, Y_census_teste = pickle.load(f)

# %%
X_census_treinamento.shape, Y_census_treinamento.shape
# Out:
# ((27676, 108), (27676,))

# %%
X_census_teste.shape, Y_census_teste.shape
# Out:
# ((4885, 108), (4885,))

# %%
Y_census_treinamento
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' >50K', ' <=50K'],
#       shape=(27676,), dtype=object)

# %%
# criando random forest implementando random forest
random_forest_census = RandomForestClassifier(n_estimators=100, criterion='entropy', random_state=0)
random_forest_census.fit(X_census_treinamento, Y_census_treinamento)

# b_estimators corresponde ao número de arvores
# Out:
# RandomForestClassifier(criterion='entropy', random_state=0)

# %%
# gerandio previsoes
previsoes = random_forest_census.predict(X_census_teste)
previsoes
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       shape=(4885,), dtype=object)

# %%
# exibindo respostas reais para comparação com as previões
Y_census_teste
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' <=50K'],
#       shape=(4885,), dtype=object)

# %%
# importando métricas
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

#precisão
accuracy_score(Y_census_teste, previsoes)
# Out:
# 0.8507676560900717

# %%
from yellowbrick.classifier import ConfusionMatrix
cm = ConfusionMatrix(random_forest_census)
cm.fit(X_census_treinamento, Y_census_treinamento)
cm.score(X_census_teste, Y_census_teste)
# Out:
# 0.8507676560900717

# %%
print(classification_report(Y_census_teste, previsoes))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.88      0.93      0.90      3693
#         >50K       0.73      0.62      0.67      1192
#
#     accuracy                           0.85      4885
#    macro avg       0.81      0.77      0.79      4885
# weighted avg       0.85      0.85      0.85      4885

# %% [markdown]
# # Aprendizado por regras

# %%
import Orange

# %%
# Carregando dados, precisamos da base no formato do orange por isso não usaremos pandas
# leitura direta do arquivo csv
# carregando uma versão atualizada da base census adicionando a notação c# no atributo classe para o orange interpretá-lo como tal
# esse algoritmo consegue trabalhar com atributos categoricos, ou seja, não hça necessidade de usar nenhum tipo de encoder
base_census = Orange.data.Table('../datasets/census_regras.csv')

# %%
# como a base e muito grande, para reduzir o tempo de trinamento vamos usar uma amostra com 10 mil registros
# Selecionando os 10.000 primeiros registros como amostra
census_amostra = base_census[:10000]
census_amostra
# Out:
# [[39, State-gov, 77516, Bachelors, 13, ... | <=50K],
#  [50, Self-emp-not-inc, 83311, Bachelors, 13, ... | <=50K],
#  [38, Private, 215646, HS-grad, 9, ... | <=50K],
#  [53, Private, 234721, 11th, 7, ... | <=50K],
#  [28, Private, 338409, Bachelors, 13, ... | <=50K],
#  ...
# ]

# %%
base_census.domain
# Out:
# [age, workclass, final-weight, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loos, hour-per-week, native-country | income]

# %%
# separando a base em treinamento e teste
base_dividida = Orange.evaluation.testing.sample(census_amostra, n=0.25)
base_dividida
# Out:
# ([[26, Self-emp-not-inc, 318644, Prof-school, 15, ... | <=50K],
#   [22, Private, 221745, Some-college, 10, ... | <=50K],
#   [25, Private, 254746, Bachelors, 13, ... | <=50K],
#   [45, Private, 34419, Bachelors, 13, ... | <=50K],
#   [36, Federal-gov, 255191, Masters, 14, ... | <=50K],
#   ...
#  ],
#  [[44, Private, 202565, HS-grad, 9, ... | <=50K],
#   [50, Private, 237735, 5th-6th, 3, ... | <=50K],
#   [48, ?, 184513, Bachelors, 13, ... | >50K],
#   [48, Private, 189462, Some-college, 10, ... | >50K],
#   [34, Private, 203408, Bachelors, 13, ... | >50K],
#   ...
#  ])

# %%
base_dividida[0]
# Out:
# [[26, Self-emp-not-inc, 318644, Prof-school, 15, ... | <=50K],
#  [22, Private, 221745, Some-college, 10, ... | <=50K],
#  [25, Private, 254746, Bachelors, 13, ... | <=50K],
#  [45, Private, 34419, Bachelors, 13, ... | <=50K],
#  [36, Federal-gov, 255191, Masters, 14, ... | <=50K],
#  ...
# ]

# %%
base_dividida[1]
# Out:
# [[44, Private, 202565, HS-grad, 9, ... | <=50K],
#  [50, Private, 237735, 5th-6th, 3, ... | <=50K],
#  [48, ?, 184513, Bachelors, 13, ... | >50K],
#  [48, Private, 189462, Some-college, 10, ... | >50K],
#  [34, Private, 203408, Bachelors, 13, ... | >50K],
#  ...
# ]

# %%
# não há necessidade de fazer a divisão entre atributos previsores e classe
# a base de treinamento esta na posição 1
base_treinamento = base_dividida[1]

# %%
base_teste = base_dividida[0]

# %%
# checando a divisão dos dados
len(base_treinamento), len(base_teste)
# Out:
# (7500, 2500)

# %%
# criando algoritmo
cn2 = Orange.classification.rules.CN2Learner()
regras_census = cn2(base_treinamento)

# %%
# visualizando regras geradas
for regras in regras_census.rule_list:
    print(regras)
# Out:
# IF workclass==Never-worked THEN income=<=50K
# IF workclass==Without-pay THEN income=<=50K
# IF education==Preschool THEN income=<=50K
# IF occupation==Armed-Forces THEN income=<=50K
# IF occupation==Priv-house-serv THEN income=<=50K
# IF native-country==Ecuador THEN income=<=50K
# IF native-country==France THEN income=<=50K
# IF native-country==Honduras THEN income=<=50K
# IF native-country==Hong THEN income=<=50K
# IF native-country==Hungary THEN income=<=50K
# IF native-country==Laos THEN income=<=50K
# IF native-country==Nicaragua THEN income=<=50K
# IF native-country==Outlying-US(Guam-USVI-etc) THEN income=<=50K
# IF native-country==Scotland THEN income=<=50K
# IF native-country==South THEN income=<=50K
# IF native-country==Trinadad&Tobago THEN income=<=50K
# IF native-country==Yugoslavia THEN income=<=50K
# IF capital-gain>=7298.0 AND workclass==Federal-gov THEN income=>50K
# IF native-country==Guatemala THEN income=<=50K
# IF capital-gain>=7298.0 AND workclass==Local-gov THEN income=>50K
# IF relationship==Own-child AND workclass==Federal-gov THEN income=<=50K
# IF relationship==Own-child AND workclass==Self-emp-inc THEN income=<=50K
# IF relationship==Own-child AND workclass==State-gov THEN income=<=50K
# IF capital-gain>=7298.0 AND workclass==Self-emp-inc THEN income=>50K
# IF relationship==Own-child AND final-weight>=258517.0 THEN income=<=50K
# IF capital-gain>=7298.0 AND workclass==State-gov THEN income=>50K
# IF capital-gain>=7298.0 AND education==5th-6th THEN income=>50K
# IF capital-gain>=7298.0 AND education==11th THEN income=>50K
# IF age<=24.0 AND workclass==Federal-gov THEN income=<=50K
# IF age<=24.0 AND workclass==Self-emp-inc THEN income=<=50K
# IF age<=24.0 AND education==5th-6th THEN income=<=50K
# IF age<=24.0 AND education==9th THEN income=<=50K
# IF age<=24.0 AND education==10th THEN income=<=50K
# IF age<=24.0 AND education==11th THEN income=<=50K
# IF capital-gain>=7298.0 AND education==Assoc-acdm THEN income=>50K
# IF capital-gain>=7298.0 AND education==Assoc-voc THEN income=>50K
# IF age<=24.0 AND education==Masters THEN income=<=50K
# IF age<=24.0 AND marital-status==Divorced THEN income=<=50K
# IF age<=24.0 AND marital-status==Married-spouse-absent THEN income=<=50K
# IF capital-gain>=7298.0 AND education==Bachelors THEN income=>50K
# IF age<=24.0 AND occupation==Craft-repair THEN income=<=50K
# IF age<=24.0 AND occupation==Farming-fishing THEN income=<=50K
# IF age<=24.0 AND occupation==Handlers-cleaners THEN income=<=50K
# IF relationship==Own-child AND final-weight>=258298.0 THEN income=>50K
# IF relationship==Own-child AND education==1st-4th THEN income=<=50K
# IF relationship==Own-child AND education==5th-6th THEN income=<=50K
# IF relationship==Own-child AND education==7th-8th THEN income=<=50K
# IF relationship==Own-child AND education==9th THEN income=<=50K
# IF age<=24.0 AND occupation==Prof-specialty THEN income=<=50K
# IF relationship==Own-child AND final-weight>=226327.0 THEN income=<=50K
# IF relationship==Own-child AND final-weight>=225399.0 THEN income=>50K
# IF relationship==Own-child AND education==11th THEN income=<=50K
# IF relationship==Own-child AND education==12th THEN income=<=50K
# IF relationship==Own-child AND education==Assoc-acdm THEN income=<=50K
# IF relationship==Own-child AND education==Assoc-voc THEN income=<=50K
# IF relationship==Own-child AND education==Doctorate THEN income=<=50K
# IF relationship==Own-child AND education==Masters THEN income=<=50K
# IF relationship==Own-child AND education==Prof-school THEN income=>50K
# IF relationship==Own-child AND marital-status==Married-spouse-absent THEN income=<=50K
# IF relationship==Own-child AND marital-status==Separated THEN income=<=50K
# IF relationship==Own-child AND marital-status==Widowed THEN income=<=50K
# IF relationship==Own-child AND occupation==Adm-clerical THEN income=<=50K
# IF relationship==Own-child AND occupation==Farming-fishing THEN income=<=50K
# IF relationship==Own-child AND occupation==Handlers-cleaners THEN income=<=50K
# IF relationship==Own-child AND occupation==Machine-op-inspct THEN income=<=50K
# IF relationship==Own-child AND occupation==Other-service THEN income=<=50K
# IF capital-gain>=7298.0 AND education==Doctorate THEN income=>50K
# IF capital-gain>=7298.0 AND education==Masters THEN income=>50K
# IF capital-gain>=7298.0 AND education==Prof-school THEN income=>50K
# IF age<=24.0 AND occupation==Tech-support THEN income=<=50K
# IF age<=24.0 AND relationship==Other-relative THEN income=<=50K
# IF age<=24.0 AND relationship==Own-child THEN income=<=50K
# IF education==1st-4th AND age>=43.0 THEN income=<=50K
# IF education==9th AND workclass==Local-gov THEN income=<=50K
# IF education==9th AND workclass!=Private THEN income=<=50K
# IF education==9th AND final-weight>=186489.0 THEN income=<=50K
# IF marital-status==Widowed AND workclass==Federal-gov THEN income=<=50K
# IF relationship==Other-relative AND age>=53.0 THEN income=<=50K
# IF relationship==Unmarried AND final-weight>=374764.0 THEN income=<=50K
# IF marital-status==Widowed AND workclass==Self-emp-not-inc THEN income=<=50K
# IF relationship==Unmarried AND final-weight>=372181.0 THEN income=>50K
# IF relationship==Unmarried AND education==1st-4th THEN income=<=50K
# IF relationship==Unmarried AND education==5th-6th THEN income=<=50K
# IF relationship==Unmarried AND education==7th-8th THEN income=<=50K
# IF relationship==Unmarried AND education==9th THEN income=<=50K
# IF relationship==Unmarried AND education==12th THEN income=<=50K
# IF relationship==Unmarried AND marital-status==Married-spouse-absent THEN income=<=50K
# IF relationship==Own-child AND occupation==Protective-serv THEN income=<=50K
# IF relationship==Unmarried AND occupation==Farming-fishing THEN income=<=50K
# IF relationship==Unmarried AND occupation==Handlers-cleaners THEN income=<=50K
# IF occupation==Other-service AND age>=59.0 THEN income=<=50K
# IF relationship==Own-child AND occupation==Tech-support THEN income=<=50K
# IF relationship==Unmarried AND race==Other THEN income=<=50K
# IF relationship==Unmarried AND capital-loos>=2258.0 THEN income=>50K
# IF relationship==Unmarried AND capital-loos>=1380.0 THEN income=<=50K
# IF relationship==Unmarried AND capital-loos>=653.0 THEN income=>50K
# IF relationship==Unmarried AND capital-loos>=213.0 THEN income=<=50K
# IF relationship==Unmarried AND native-country==Cambodia THEN income=<=50K
# IF relationship==Unmarried AND native-country==Canada THEN income=<=50K
# IF relationship==Unmarried AND native-country==China THEN income=<=50K
# IF relationship==Unmarried AND native-country==Columbia THEN income=<=50K
# IF relationship==Unmarried AND native-country==Cuba THEN income=<=50K
# IF relationship==Unmarried AND native-country==El-Salvador THEN income=<=50K
# IF relationship==Unmarried AND native-country==England THEN income=<=50K
# IF relationship==Unmarried AND native-country==Germany THEN income=<=50K
# IF relationship==Unmarried AND native-country==Haiti THEN income=<=50K
# IF relationship==Unmarried AND native-country==Ireland THEN income=<=50K
# IF relationship==Unmarried AND native-country==Italy THEN income=<=50K
# IF relationship==Unmarried AND native-country==Jamaica THEN income=<=50K
# IF relationship==Unmarried AND native-country==Mexico THEN income=<=50K
# IF relationship==Unmarried AND native-country==Peru THEN income=<=50K
# IF relationship==Unmarried AND native-country==Puerto-Rico THEN income=<=50K
# IF relationship==Unmarried AND native-country==Thailand THEN income=<=50K
# IF marital-status==Widowed AND workclass==State-gov THEN income=<=50K
# IF marital-status==Widowed AND education==7th-8th THEN income=<=50K
# IF relationship==Other-relative AND workclass==Federal-gov THEN income=<=50K
# IF relationship==Other-relative AND workclass==Local-gov THEN income=<=50K
# IF relationship==Own-child AND occupation==Transport-moving THEN income=<=50K
# IF relationship==Other-relative AND workclass==State-gov THEN income=<=50K
# IF education==11th AND age>=65.0 THEN income=<=50K
# IF relationship==Other-relative AND education==5th-6th THEN income=<=50K
# IF marital-status==Widowed AND education==10th THEN income=<=50K
# IF occupation==Other-service AND workclass==Federal-gov THEN income=<=50K
# IF occupation==Other-service AND workclass==State-gov THEN income=<=50K
# IF marital-status==Widowed AND education==11th THEN income=<=50K
# IF relationship==Other-relative AND education==7th-8th THEN income=<=50K
# IF marital-status==Never-married AND education==1st-4th THEN income=<=50K
# IF marital-status==Never-married AND education==5th-6th THEN income=<=50K
# IF marital-status==Never-married AND education==7th-8th THEN income=<=50K
# IF marital-status==Never-married AND education==9th THEN income=<=50K
# IF marital-status==Never-married AND education==Assoc-acdm THEN income=<=50K
# IF marital-status==Widowed AND education==12th THEN income=<=50K
# IF marital-status==Widowed AND education==Assoc-acdm THEN income=<=50K
# IF occupation==Other-service AND education==1st-4th THEN income=<=50K
# IF occupation==Other-service AND education==5th-6th THEN income=<=50K
# IF relationship==Other-relative AND education==9th THEN income=<=50K
# IF marital-status==Never-married AND occupation==Farming-fishing THEN income=<=50K
# IF occupation==Other-service AND education==7th-8th THEN income=<=50K
# IF occupation==Other-service AND final-weight>=387430.0 THEN income=<=50K
# IF marital-status==Widowed AND education==Assoc-voc THEN income=<=50K
# IF relationship==Other-relative AND education==10th THEN income=<=50K
# IF relationship==Own-child AND race==Amer-Indian-Eskimo THEN income=<=50K
# IF marital-status==Never-married AND occupation==Handlers-cleaners THEN income=<=50K
# IF relationship==Own-child AND race==Asian-Pac-Islander THEN income=<=50K
# IF occupation==Other-service AND education==9th THEN income=<=50K
# IF marital-status==Never-married AND occupation==Machine-op-inspct THEN income=<=50K
# IF occupation==Other-service AND education==10th THEN income=<=50K
# IF education==11th AND workclass==Federal-gov THEN income=<=50K
# IF relationship==Own-child AND race==Black THEN income=<=50K
# IF education==11th AND workclass==State-gov THEN income=<=50K
# IF relationship==Unmarried AND native-country==India THEN income=>50K
# IF marital-status==Widowed AND education==Prof-school THEN income=<=50K
# IF marital-status==Widowed AND occupation==Craft-repair THEN income=<=50K
# IF marital-status==Widowed AND occupation==Exec-managerial THEN income=<=50K
# IF occupation==Other-service AND education==11th THEN income=<=50K
# IF marital-status==Never-married AND relationship==Other-relative THEN income=<=50K
# IF native-country==Cambodia THEN income=>50K
# IF marital-status==Widowed AND workclass==Self-emp-inc THEN income=>50K
# IF marital-status==Widowed AND occupation==Farming-fishing THEN income=<=50K
# IF marital-status==Widowed AND occupation==Machine-op-inspct THEN income=<=50K
# IF marital-status==Widowed AND occupation==Other-service THEN income=<=50K
# IF marital-status==Never-married AND race==Amer-Indian-Eskimo THEN income=<=50K
# IF marital-status==Never-married AND capital-gain>=8614.0 THEN income=>50K
# IF relationship==Unmarried AND final-weight>=343121.0 THEN income=<=50K
# IF marital-status==Never-married AND native-country==Canada THEN income=<=50K
# IF marital-status==Never-married AND native-country==China THEN income=<=50K
# IF marital-status==Never-married AND native-country==Cuba THEN income=<=50K
# IF marital-status==Never-married AND native-country==Dominican-Republic THEN income=<=50K
# IF marital-status==Never-married AND native-country==England THEN income=<=50K
# IF marital-status==Never-married AND native-country==Germany THEN income=<=50K
# IF marital-status==Never-married AND native-country==Haiti THEN income=<=50K
# IF marital-status==Never-married AND native-country==Iran THEN income=<=50K
# IF marital-status==Never-married AND native-country==Italy THEN income=>50K
# IF marital-status==Never-married AND native-country==Jamaica THEN income=<=50K
# IF marital-status==Never-married AND native-country==Japan THEN income=<=50K
# IF marital-status==Never-married AND native-country==Mexico THEN income=<=50K
# IF marital-status==Never-married AND native-country==Poland THEN income=<=50K
# IF marital-status==Never-married AND native-country==Vietnam THEN income=<=50K
# IF relationship==Own-child AND capital-gain>=7688.0 THEN income=>50K
# IF relationship==Own-child AND capital-gain>=2174.0 THEN income=<=50K
# IF relationship==Own-child AND marital-status==Married-civ-spouse THEN income=>50K
# IF relationship==Own-child AND education==HS-grad THEN income=<=50K
# IF marital-status==Widowed AND age>=75.0 THEN income=<=50K
# IF capital-loos>=2392.0 AND workclass!=Private THEN income=>50K
# IF occupation==Other-service AND education==Masters THEN income=<=50K
# IF marital-status==Married-spouse-absent AND workclass==Local-gov THEN income=<=50K
# IF relationship==Own-child AND occupation==Sales THEN income=<=50K
# IF occupation==Other-service AND marital-status==Married-spouse-absent THEN income=<=50K
# IF occupation==Other-service AND relationship==Other-relative THEN income=<=50K
# IF native-country==Puerto-Rico AND age>=32.0 THEN income=<=50K
# IF occupation==Other-service AND race==Amer-Indian-Eskimo THEN income=<=50K
# IF occupation==Other-service AND race==Other THEN income=<=50K
# IF occupation==Other-service AND capital-gain>=4386.0 THEN income=>50K
# IF occupation==Other-service AND capital-gain>=2635.0 THEN income=<=50K
# IF occupation==Other-service AND capital-loos>=2559.0 THEN income=>50K
# IF age<=24.0 AND marital-status==Separated THEN income=<=50K
# IF age<=24.0 AND relationship==Unmarried THEN income=<=50K
# IF age<=24.0 AND race==Asian-Pac-Islander THEN income=<=50K
# IF occupation==Other-service AND marital-status==Separated THEN income=<=50K
# IF occupation==Other-service AND native-country==Canada THEN income=<=50K
# IF occupation==Other-service AND native-country==England THEN income=<=50K
# IF occupation==Other-service AND native-country==Germany THEN income=<=50K
# IF occupation==Other-service AND native-country==Greece THEN income=<=50K
# IF occupation==Other-service AND native-country==Ireland THEN income=<=50K
# IF native-country==Ireland THEN income=>50K
# IF occupation==Other-service AND native-country==Italy THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND education==5th-6th THEN income=<=50K
# IF occupation==Other-service AND native-country==Japan THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND education==9th THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND occupation==Farming-fishing THEN income=<=50K
# IF occupation==Other-service AND native-country==Mexico THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND occupation==Handlers-cleaners THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND relationship==Husband THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND capital-gain>=8614.0 THEN income=>50K
# IF marital-status==Widowed AND occupation==Adm-clerical THEN income=<=50K
# IF marital-status==Married-spouse-absent AND workclass==Self-emp-inc THEN income=<=50K
# IF marital-status==Married-spouse-absent AND workclass==State-gov THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND native-country==Canada THEN income=<=50K
# IF age<=24.0 AND race==Black THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND native-country==China THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND native-country==Cuba THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND native-country==Dominican-Republic THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND native-country==El-Salvador THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND native-country==England THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND native-country==Germany THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND native-country==Haiti THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND native-country==Poland THEN income=<=50K
# IF marital-status==Divorced AND education==7th-8th THEN income=<=50K
# IF marital-status==Divorced AND race==Other THEN income=<=50K
# IF marital-status==Divorced AND capital-loos>=2559.0 THEN income=>50K
# IF marital-status==Divorced AND education==Prof-school THEN income=<=50K
# IF marital-status==Divorced AND capital-loos>=1590.0 THEN income=<=50K
# IF marital-status==Divorced AND capital-loos>=1564.0 THEN income=>50K
# IF marital-status!=Married-civ-spouse AND native-country==Iran THEN income=<=50K
# IF marital-status==Divorced AND capital-loos>=1408.0 THEN income=<=50K
# IF marital-status==Divorced AND native-country==Italy THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND native-country==Italy THEN income=>50K
# IF marital-status==Married-spouse-absent AND age>=49.0 THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND education==7th-8th THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND native-country==Columbia THEN income=>50K
# IF occupation==Other-service AND native-country==Philippines THEN income=<=50K
# IF occupation==Other-service AND native-country==Vietnam THEN income=<=50K
# IF relationship==Not-in-family AND occupation==Farming-fishing THEN income=>50K
# IF relationship==Not-in-family AND race==Amer-Indian-Eskimo THEN income=<=50K
# IF relationship==Not-in-family AND native-country==China THEN income=<=50K
# IF relationship==Not-in-family AND native-country==Jamaica THEN income=>50K
# IF marital-status==Married-spouse-absent AND workclass!=Private THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND native-country==Jamaica THEN income=<=50K
# IF marital-status==Married-spouse-absent AND final-weight>=96102.0 THEN income=<=50K
# IF education==11th AND final-weight>=247151.0 THEN income=<=50K
# IF relationship==Own-child AND education==10th THEN income=>50K
# IF relationship==Own-child AND workclass==Self-emp-not-inc THEN income=<=50K
# IF relationship==Own-child AND capital-loos>=1340.0 THEN income=<=50K
# IF marital-status==Divorced AND education==10th THEN income=<=50K
# IF capital-gain>=5178.0 AND workclass==Federal-gov THEN income=>50K
# IF capital-gain>=5178.0 AND workclass==Self-emp-inc THEN income=>50K
# IF marital-status==Separated AND workclass==State-gov THEN income=<=50K
# IF capital-gain>=5178.0 AND education==9th THEN income=>50K
# IF capital-gain>=5178.0 AND education==Assoc-voc THEN income=<=50K
# IF capital-gain>=5178.0 AND education==Masters THEN income=<=50K
# IF capital-gain>=5178.0 AND education==Prof-school THEN income=>50K
# IF capital-gain>=5178.0 AND marital-status==Divorced THEN income=<=50K
# IF capital-gain>=5178.0 AND workclass==Local-gov THEN income=>50K
# IF capital-gain>=5178.0 AND marital-status!=Married-civ-spouse THEN income=<=50K
# IF capital-gain>=5178.0 AND education==Bachelors THEN income=>50K
# IF capital-gain>=5178.0 AND occupation==Adm-clerical THEN income=>50K
# IF capital-gain>=5178.0 AND occupation==Farming-fishing THEN income=>50K
# IF capital-gain>=5178.0 AND occupation==Machine-op-inspct THEN income=>50K
# IF capital-gain>=5178.0 AND occupation==Prof-specialty THEN income=>50K
# IF capital-gain>=5178.0 AND occupation==Sales THEN income=>50K
# IF native-country==El-Salvador THEN income=<=50K
# IF capital-gain>=5178.0 AND age>=62.0 THEN income=<=50K
# IF capital-gain>=5178.0 THEN income=>50K
# IF capital-gain>=5013.0 THEN income=<=50K
# IF relationship==Unmarried AND capital-gain>=4934.0 THEN income=>50K
# IF relationship==Unmarried AND workclass==Local-gov THEN income=<=50K
# IF age<=27.0 AND workclass==Federal-gov THEN income=<=50K
# IF age<=27.0 AND final-weight>=367329.0 THEN income=<=50K
# IF relationship==Unmarried AND occupation==Protective-serv THEN income=>50K
# IF relationship==Unmarried AND race==Amer-Indian-Eskimo THEN income=<=50K
# IF relationship==Unmarried AND capital-gain>=1151.0 THEN income=<=50K
# IF age<=27.0 AND final-weight>=359155.0 THEN income=>50K
# IF age<=27.0 AND education==5th-6th THEN income=<=50K
# IF age<=27.0 AND education==10th THEN income=<=50K
# IF age<=27.0 AND education==11th THEN income=<=50K
# IF age<=27.0 AND education==Doctorate THEN income=<=50K
# IF age<=27.0 AND education==Masters THEN income=<=50K
# IF age<=27.0 AND marital-status==Divorced THEN income=<=50K
# IF age<=27.0 AND occupation==Farming-fishing THEN income=<=50K
# IF age<=27.0 AND occupation==Machine-op-inspct THEN income=<=50K
# IF native-country==Puerto-Rico THEN income=>50K
# IF native-country==Mexico AND workclass==Self-emp-not-inc THEN income=>50K
# IF native-country==Mexico AND workclass==State-gov THEN income=>50K
# IF native-country==Mexico AND final-weight>=288273.0 THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND native-country==Mexico THEN income=<=50K
# IF relationship==Not-in-family AND marital-status==Married-civ-spouse THEN income=>50K
# IF occupation==Farming-fishing AND workclass==Local-gov THEN income=<=50K
# IF marital-status==Separated AND education==10th THEN income=<=50K
# IF occupation==Farming-fishing AND workclass==State-gov THEN income=<=50K
# IF marital-status==Separated AND education==11th THEN income=<=50K
# IF occupation==Farming-fishing AND age>=63.0 THEN income=<=50K
# IF native-country==Mexico AND final-weight>=286370.0 THEN income=>50K
# IF native-country==Mexico AND education==7th-8th THEN income=<=50K
# IF native-country==Mexico AND education==12th THEN income=<=50K
# IF native-country==Mexico AND education==Assoc-voc THEN income=<=50K
# IF native-country==Mexico AND workclass!=Private THEN income=>50K
# IF native-country==Mexico AND age>=42.0 THEN income=<=50K
# IF marital-status==Separated AND education==Assoc-voc THEN income=<=50K
# IF native-country==Mexico AND education==5th-6th THEN income=<=50K
# IF age<=30.0 AND education==9th THEN income=<=50K
# IF age<=30.0 AND education==10th THEN income=<=50K
# IF age<=30.0 AND education==Doctorate THEN income=>50K
# IF age<=30.0 AND marital-status==Divorced THEN income=<=50K
# IF age<=27.0 AND relationship==Own-child THEN income=<=50K
# IF age<=27.0 AND relationship==Unmarried THEN income=<=50K
# IF age<=24.0 AND education==7th-8th THEN income=>50K
# IF age<=27.0 AND education==7th-8th THEN income=<=50K
# IF age<=27.0 AND race==Black THEN income=<=50K
# IF age<=24.0 AND workclass==Self-emp-not-inc THEN income=<=50K
# IF age<=24.0 AND occupation==Transport-moving THEN income=<=50K
# IF marital-status==Widowed AND occupation==Protective-serv THEN income=>50K
# IF marital-status==Widowed AND age>=71.0 THEN income=<=50K
# IF marital-status==Widowed AND workclass==Local-gov THEN income=<=50K
# IF marital-status==Separated AND education==Doctorate THEN income=>50K
# IF marital-status==Separated AND education==Masters THEN income=>50K
# IF marital-status==Separated AND education==Prof-school THEN income=>50K
# IF relationship==Unmarried AND final-weight>=340428.0 THEN income=>50K
# IF relationship==Unmarried AND education==Prof-school THEN income=<=50K
# IF age<=24.0 AND race==Other THEN income=<=50K
# IF marital-status==Separated AND workclass==Self-emp-inc THEN income=<=50K
# IF marital-status==Separated AND workclass==Self-emp-not-inc THEN income=<=50K
# IF marital-status==Separated AND occupation==Craft-repair THEN income=<=50K
# IF marital-status==Separated AND occupation==Protective-serv THEN income=<=50K
# IF marital-status==Separated AND occupation==Sales THEN income=<=50K
# IF marital-status==Separated AND occupation==Transport-moving THEN income=<=50K
# IF marital-status==Separated AND relationship==Other-relative THEN income=<=50K
# IF marital-status==Separated AND race==Asian-Pac-Islander THEN income=>50K
# IF marital-status==Separated AND race==Black THEN income=<=50K
# IF marital-status==Widowed AND final-weight>=273569.0 THEN income=<=50K
# IF relationship==Own-child AND final-weight>=213179.0 THEN income=>50K
# IF relationship==Own-child AND final-weight>=156464.0 THEN income=<=50K
# IF education==11th AND final-weight>=244903.0 THEN income=>50K
# IF education==11th AND workclass==Local-gov THEN income=<=50K
# IF education==11th AND final-weight>=214689.0 THEN income=<=50K
# IF education==11th AND final-weight>=210295.0 THEN income=>50K
# IF education==11th AND workclass==Self-emp-inc THEN income=<=50K
# IF education==11th AND final-weight>=187046.0 THEN income=<=50K
# IF age<=30.0 AND education==7th-8th THEN income=<=50K
# IF age<=30.0 AND education==11th THEN income=<=50K
# IF age<=30.0 AND marital-status==Married-spouse-absent THEN income=<=50K
# IF age<=30.0 AND relationship==Own-child THEN income=<=50K
# IF age<=30.0 AND race==Other THEN income=<=50K
# IF marital-status==Never-married AND race==Other THEN income=>50K
# IF marital-status==Never-married AND native-country==India THEN income=<=50K
# IF race==Other AND workclass==Private THEN income=<=50K
# IF age<=30.0 AND capital-gain>=4416.0 THEN income=<=50K
# IF age<=24.0 AND capital-gain>=2463.0 THEN income=<=50K
# IF age<=30.0 AND capital-gain>=4386.0 THEN income=>50K
# IF age<=30.0 AND capital-gain>=3325.0 THEN income=<=50K
# IF age<=30.0 AND capital-gain>=3103.0 THEN income=>50K
# IF age<=30.0 AND capital-gain>=2174.0 THEN income=<=50K
# IF age<=30.0 AND native-country==China THEN income=<=50K
# IF age<=30.0 AND native-country==Columbia THEN income=<=50K
# IF age<=30.0 AND native-country==England THEN income=<=50K
# IF age<=30.0 AND native-country==Germany THEN income=<=50K
# IF native-country==Germany AND age>=46.0 THEN income=>50K
# IF marital-status==Separated AND workclass==Federal-gov THEN income=>50K
# IF marital-status==Separated AND age>=45.0 THEN income=<=50K
# IF age<=30.0 AND native-country==Haiti THEN income=<=50K
# IF age<=30.0 AND native-country==Iran THEN income=<=50K
# IF occupation==Farming-fishing AND education==1st-4th THEN income=<=50K
# IF age<=30.0 AND native-country==Jamaica THEN income=>50K
# IF age<=30.0 AND native-country==Philippines THEN income=<=50K
# IF age<=30.0 AND native-country==Taiwan THEN income=<=50K
# IF marital-status==Never-married AND native-country==Taiwan THEN income=>50K
# IF age<=30.0 AND native-country==Thailand THEN income=>50K
# IF native-country==Thailand THEN income=<=50K
# IF occupation==Farming-fishing AND education==5th-6th THEN income=<=50K
# IF occupation==Farming-fishing AND education==7th-8th THEN income=<=50K
# IF occupation==Adm-clerical AND education==10th THEN income=<=50K
# IF relationship==Unmarried AND education==10th THEN income=>50K
# IF relationship==Unmarried AND occupation==Transport-moving THEN income=<=50K
# IF occupation==Adm-clerical AND education==12th THEN income=<=50K
# IF native-country==Poland AND workclass!=Private THEN income=<=50K
# IF occupation==Adm-clerical AND education==Doctorate THEN income=>50K
# IF occupation==Adm-clerical AND education==Prof-school THEN income=<=50K
# IF occupation==Adm-clerical AND hour-per-week>=80.0 THEN income=>50K
# IF occupation==Adm-clerical AND native-country==Canada THEN income=>50K
# IF occupation==Adm-clerical AND native-country==Cuba THEN income=>50K
# IF occupation==Adm-clerical AND native-country==India THEN income=<=50K
# IF occupation==Adm-clerical AND native-country==Iran THEN income=>50K
# IF occupation==Adm-clerical AND native-country==Italy THEN income=>50K
# IF occupation==Adm-clerical AND native-country==Jamaica THEN income=<=50K
# IF occupation==Adm-clerical AND native-country==Mexico THEN income=<=50K
# IF occupation==Adm-clerical AND native-country==Vietnam THEN income=<=50K
# IF relationship!=Husband AND education==7th-8th THEN income=>50K
# IF relationship!=Husband AND education==9th THEN income=<=50K
# IF relationship!=Husband AND occupation==Farming-fishing THEN income=<=50K
# IF relationship!=Husband AND native-country==Canada THEN income=>50K
# IF relationship!=Husband AND native-country==China THEN income=<=50K
# IF relationship!=Husband AND native-country==Dominican-Republic THEN income=>50K
# IF native-country==Dominican-Republic THEN income=<=50K
# IF relationship!=Husband AND native-country==Greece THEN income=<=50K
# IF relationship!=Husband AND native-country==Haiti THEN income=<=50K
# IF relationship!=Husband AND native-country==India THEN income=<=50K
# IF age<=30.0 AND relationship==Other-relative THEN income=>50K
# IF relationship!=Husband AND native-country==Jamaica THEN income=>50K
# IF occupation==Other-service AND native-country==Jamaica THEN income=<=50K
# IF native-country==Jamaica THEN income=>50K
# IF relationship!=Husband AND native-country==Mexico THEN income=>50K
# IF native-country==Mexico AND education!=1st-4th THEN income=<=50K
# IF relationship!=Husband AND native-country==Peru THEN income=<=50K
# IF relationship!=Husband AND native-country==Portugal THEN income=>50K
# IF native-country==Portugal THEN income=<=50K
# IF relationship!=Husband AND native-country==Taiwan THEN income=<=50K
# IF relationship!=Husband AND native-country==Vietnam THEN income=>50K
# IF native-country==Vietnam THEN income=<=50K
# IF relationship!=Husband AND education==5th-6th THEN income=<=50K
# IF relationship!=Husband AND native-country==Italy THEN income=>50K
# IF capital-loos>=1848.0 AND workclass==Self-emp-inc THEN income=>50K
# IF marital-status==Separated AND final-weight>=344073.0 THEN income=>50K
# IF marital-status==Separated AND education==Assoc-acdm THEN income=<=50K
# IF marital-status==Separated AND education==HS-grad THEN income=<=50K
# IF occupation==Adm-clerical AND marital-status==Separated THEN income=<=50K
# IF relationship==Other-relative AND workclass!=Private THEN income=<=50K
# IF capital-loos>=1848.0 AND education==10th THEN income=>50K
# IF marital-status==Never-married AND education==10th THEN income=<=50K
# IF relationship!=Husband AND education==10th THEN income=<=50K
# IF occupation==Farming-fishing AND education==10th THEN income=<=50K
# IF capital-loos>=1848.0 AND education==11th THEN income=<=50K
# IF capital-loos>=1848.0 AND education==Doctorate THEN income=>50K
# IF hour-per-week<=35.0 AND workclass==Federal-gov THEN income=<=50K
# IF hour-per-week<=35.0 AND education==7th-8th THEN income=<=50K
# IF capital-loos>=1848.0 AND education==Prof-school THEN income=>50K
# IF occupation==Farming-fishing AND education==Assoc-acdm THEN income=<=50K
# IF hour-per-week<=35.0 AND final-weight>=509364.0 THEN income=<=50K
# IF hour-per-week<=35.0 AND final-weight>=506858.0 THEN income=>50K
# IF hour-per-week<=35.0 AND education==9th THEN income=<=50K
# IF hour-per-week<=35.0 AND education==11th THEN income=<=50K
# IF hour-per-week<=35.0 AND marital-status==Married-AF-spouse THEN income=<=50K
# IF marital-status==Married-AF-spouse THEN income=>50K
# IF hour-per-week<=35.0 AND marital-status==Separated THEN income=<=50K
# IF hour-per-week<=35.0 AND relationship==Other-relative THEN income=<=50K
# IF sex==Female AND education==12th THEN income=<=50K
# IF marital-status==Divorced AND education==12th THEN income=>50K
# IF occupation==Farming-fishing AND education==Some-college THEN income=<=50K
# IF age<=30.0 AND occupation==Farming-fishing THEN income=>50K
# IF sex==Female AND marital-status==Married-spouse-absent THEN income=<=50K
# IF marital-status==Married-spouse-absent THEN income=>50K
# IF sex==Female AND relationship==Other-relative THEN income=<=50K
# IF sex==Female AND native-country==Japan THEN income=>50K
# IF marital-status!=Married-civ-spouse AND native-country==Japan THEN income=<=50K
# IF marital-status==Never-married AND occupation==Other-service AND workclass==Local-gov THEN income=<=50K
# IF marital-status==Never-married AND occupation==Other-service AND workclass!=Private THEN income=<=50K
# IF marital-status==Never-married AND occupation==Other-service AND final-weight>=141642.0 THEN income=<=50K
# IF capital-loos>=1848.0 AND marital-status==Never-married THEN income=<=50K
# IF capital-loos>=1848.0 AND marital-status!=Married-civ-spouse THEN income=>50K
# IF relationship==Not-in-family AND occupation==Machine-op-inspct THEN income=<=50K
# IF capital-loos>=1848.0 AND occupation==Exec-managerial THEN income=>50K
# IF capital-loos>=2002.0 AND workclass==Federal-gov THEN income=<=50K
# IF capital-loos>=2002.0 AND workclass==Local-gov THEN income=<=50K
# IF occupation==Other-service AND capital-loos>=1902.0 THEN income=>50K
# IF occupation==Other-service AND capital-loos>=1719.0 THEN income=<=50K
# IF occupation==Other-service AND hour-per-week>=60.0 THEN income=<=50K
# IF occupation==Other-service AND workclass==Self-emp-inc THEN income=>50K
# IF occupation==Other-service AND hour-per-week>=56.0 THEN income=>50K
# IF relationship==Unmarried AND occupation==Other-service THEN income=<=50K
# IF relationship==Unmarried AND age>=56.0 THEN income=<=50K
# IF occupation==Other-service AND hour-per-week>=48.0 THEN income=<=50K
# IF capital-loos>=2002.0 AND education==7th-8th THEN income=<=50K
# IF marital-status==Widowed AND age>=63.0 THEN income=<=50K
# IF capital-loos>=2002.0 AND education==Assoc-acdm THEN income=<=50K
# IF capital-loos>=2002.0 AND education==Assoc-voc THEN income=<=50K
# IF capital-loos>=1848.0 AND workclass==Federal-gov THEN income=>50K
# IF capital-loos>=1848.0 AND education==7th-8th THEN income=>50K
# IF capital-loos>=1848.0 AND education==Assoc-acdm THEN income=>50K
# IF capital-loos>=1848.0 AND education==Assoc-voc THEN income=>50K
# IF capital-loos>=1848.0 AND education==Bachelors THEN income=>50K
# IF native-country==Peru THEN income=<=50K
# IF capital-loos>=2002.0 AND workclass!=Private THEN income=<=50K
# IF capital-loos>=2042.0 AND education==HS-grad THEN income=<=50K
# IF capital-loos>=1848.0 AND workclass==Self-emp-not-inc THEN income=>50K
# IF capital-loos>=2051.0 AND education==Masters THEN income=<=50K
# IF capital-loos>=1848.0 AND occupation==Machine-op-inspct THEN income=>50K
# IF capital-loos>=1848.0 AND occupation==Protective-serv THEN income=>50K
# IF capital-loos>=1848.0 AND occupation==Sales THEN income=>50K
# IF capital-loos>=1848.0 AND occupation==Tech-support THEN income=>50K
# IF occupation==Farming-fishing AND age>=54.0 THEN income=<=50K
# IF education==10th AND workclass==Local-gov THEN income=<=50K
# IF hour-per-week<=35.0 AND education==12th THEN income=>50K
# IF occupation==Other-service AND education==12th THEN income=<=50K
# IF hour-per-week<=35.0 AND relationship==Unmarried THEN income=<=50K
# IF capital-loos>=1848.0 AND race==Black THEN income=>50K
# IF native-country==Poland AND final-weight>=319733.0 THEN income=>50K
# IF native-country==Poland THEN income=<=50K
# IF age>=63.0 AND age>=77.0 THEN income=<=50K
# IF capital-loos>=1848.0 AND native-country==Canada THEN income=>50K
# IF marital-status==Never-married AND occupation==Adm-clerical AND workclass==Federal-gov THEN income=<=50K
# IF marital-status==Never-married AND occupation==Adm-clerical AND workclass==Local-gov THEN income=<=50K
# IF education==10th AND workclass!=Private THEN income=<=50K
# IF marital-status==Never-married AND occupation==Adm-clerical AND workclass!=Private THEN income=<=50K
# IF marital-status==Never-married AND occupation==Adm-clerical AND education==Bachelors THEN income=<=50K
# IF relationship==Unmarried AND occupation==Adm-clerical AND workclass==Federal-gov THEN income=<=50K
# IF occupation==Adm-clerical AND final-weight>=283767.0 AND workclass==Federal-gov THEN income=<=50K
# IF marital-status==Never-married AND occupation==Adm-clerical AND education==HS-grad THEN income=<=50K
# IF marital-status==Never-married AND capital-gain>=4787.0 THEN income=>50K
# IF marital-status==Never-married AND capital-gain>=2050.0 THEN income=<=50K
# IF occupation==Adm-clerical AND capital-gain>=4386.0 THEN income=>50K
# IF occupation==Adm-clerical AND capital-gain>=3411.0 THEN income=<=50K
# IF occupation==Adm-clerical AND capital-gain>=3103.0 THEN income=>50K
# IF occupation==Adm-clerical AND capital-gain>=2202.0 THEN income=<=50K
# IF relationship==Unmarried AND occupation==Adm-clerical AND workclass!=Private THEN income=<=50K
# IF relationship==Unmarried AND occupation==Adm-clerical AND final-weight>=147653.0 THEN income=<=50K
# IF relationship==Unmarried AND final-weight>=319560.0 THEN income=>50K
# IF relationship==Unmarried AND occupation==Craft-repair THEN income=<=50K
# IF relationship==Unmarried AND education==11th THEN income=>50K
# IF marital-status==Divorced AND education==11th THEN income=<=50K
# IF education==11th AND final-weight>=186934.0 THEN income=>50K
# IF education==11th AND final-weight>=158592.0 THEN income=<=50K
# IF education==9th AND occupation==Craft-repair THEN income=<=50K
# IF relationship==Own-child AND final-weight>=133963.0 THEN income=>50K
# IF marital-status==Never-married AND relationship==Own-child THEN income=<=50K
# IF relationship==Own-child AND workclass==Local-gov THEN income=<=50K
# IF marital-status==Divorced AND occupation==Adm-clerical AND workclass==Federal-gov THEN income=<=50K
# IF marital-status==Divorced AND occupation==Adm-clerical AND workclass==State-gov THEN income=<=50K
# IF occupation==Machine-op-inspct AND workclass==Federal-gov THEN income=<=50K
# IF education==7th-8th AND age>=61.0 THEN income=<=50K
# IF marital-status==Divorced AND occupation==Adm-clerical AND education==Assoc-acdm THEN income=<=50K
# IF occupation==Machine-op-inspct AND workclass==State-gov THEN income=>50K
# IF occupation==Machine-op-inspct AND education==1st-4th THEN income=>50K
# IF education==1st-4th THEN income=<=50K
# IF occupation==Machine-op-inspct AND education==9th THEN income=<=50K
# IF occupation==Machine-op-inspct AND final-weight>=503923.0 THEN income=>50K
# IF occupation==Machine-op-inspct AND education==11th THEN income=<=50K
# IF occupation==Machine-op-inspct AND education==12th THEN income=<=50K
# IF occupation==Machine-op-inspct AND education==Masters THEN income=<=50K
# IF occupation==Machine-op-inspct AND race==Amer-Indian-Eskimo THEN income=<=50K
# IF occupation==Machine-op-inspct AND race==Asian-Pac-Islander THEN income=<=50K
# IF occupation==Machine-op-inspct AND capital-loos>=1672.0 THEN income=<=50K
# IF occupation==Machine-op-inspct AND native-country==Cuba THEN income=>50K
# IF occupation==Machine-op-inspct AND native-country==Haiti THEN income=<=50K
# IF native-country==Haiti THEN income=>50K
# IF occupation==Machine-op-inspct AND native-country==Italy THEN income=<=50K
# IF marital-status==Never-married AND education==HS-grad AND age>=35.0 THEN income=<=50K
# IF marital-status==Divorced AND education==Assoc-voc AND age>=37.0 THEN income=<=50K
# IF relationship==Not-in-family AND occupation==Adm-clerical AND education==Masters THEN income=<=50K
# IF relationship==Not-in-family AND occupation==Adm-clerical AND education==Some-college THEN income=<=50K
# IF relationship==Unmarried AND education==HS-grad AND workclass==Self-emp-not-inc THEN income=<=50K
# IF relationship==Unmarried AND education==HS-grad AND marital-status!=Divorced THEN income=<=50K
# IF relationship==Unmarried AND marital-status==Widowed THEN income=>50K
# IF marital-status==Widowed AND education==Some-college THEN income=<=50K
# IF marital-status==Never-married AND occupation==Other-service AND final-weight>=137618.0 THEN income=>50K
# IF marital-status==Never-married AND occupation==Other-service THEN income=<=50K
# IF age<=27.0 AND workclass==Self-emp-inc THEN income=<=50K
# IF age<=27.0 AND capital-loos>=1590.0 THEN income=<=50K
# IF marital-status!=Married-civ-spouse AND capital-gain>=4865.0 THEN income=<=50K
# IF marital-status==Divorced AND capital-gain>=4787.0 THEN income=>50K
# IF marital-status==Divorced AND capital-gain>=2174.0 THEN income=<=50K
# IF occupation==Other-service AND age>=53.0 THEN income=<=50K
# IF capital-gain>=4386.0 AND workclass==Federal-gov THEN income=>50K
# IF relationship!=Husband AND capital-gain>=3464.0 THEN income=<=50K
# IF age<=27.0 AND marital-status!=Married-civ-spouse AND workclass==Local-gov THEN income=<=50K
# IF age<=27.0 AND marital-status!=Married-civ-spouse AND education==Bachelors THEN income=<=50K
# IF occupation==Farming-fishing AND final-weight>=216292.0 THEN income=<=50K
# IF capital-gain>=4386.0 AND workclass==Self-emp-inc THEN income=>50K
# IF occupation==Handlers-cleaners AND age>=60.0 THEN income=<=50K
# IF education==5th-6th AND age>=49.0 THEN income=<=50K
# IF relationship==Unmarried AND education==HS-grad AND occupation==Adm-clerical THEN income=<=50K
# IF marital-status==Divorced AND occupation==Transport-moving AND workclass==Local-gov THEN income=<=50K
# IF marital-status==Divorced AND race==Black AND workclass==Local-gov THEN income=<=50K
# IF relationship==Not-in-family AND occupation==Sales AND workclass!=Private THEN income=<=50K
# IF marital-status==Never-married AND education==Some-college AND workclass==Federal-gov THEN income=<=50K
# IF marital-status==Divorced AND occupation==Adm-clerical AND education==Assoc-voc THEN income=<=50K
# IF relationship==Unmarried AND education==HS-grad AND occupation==Machine-op-inspct THEN income=<=50K
# IF capital-gain>=4386.0 AND final-weight>=238638.0 THEN income=>50K
# IF capital-gain>=3137.0 AND age>=54.0 THEN income=<=50K
# IF occupation==Machine-op-inspct AND native-country==England THEN income=>50K
# IF education==Doctorate AND workclass==Federal-gov THEN income=>50K
# IF occupation==Machine-op-inspct AND race==Black AND education==10th THEN income=<=50K
# IF occupation==Machine-op-inspct AND race==Black AND education==Bachelors THEN income=<=50K
# IF occupation==Machine-op-inspct AND race==Black AND education!=HS-grad THEN income=<=50K
# IF marital-status==Never-married AND education==Some-college AND workclass==Self-emp-not-inc THEN income=<=50K
# IF relationship==Not-in-family AND occupation==Sales AND education==11th THEN income=<=50K
# IF relationship==Not-in-family AND education==11th THEN income=>50K
# IF education==11th AND occupation==Craft-repair THEN income=<=50K
# IF marital-status==Divorced AND occupation==Adm-clerical AND education==Some-college THEN income=<=50K
# IF native-country==Greece AND education==Assoc-voc THEN income=<=50K
# IF native-country==Iran AND age>=38.0 THEN income=>50K
# IF native-country==Italy AND age>=47.0 THEN income=>50K
# IF native-country==Italy THEN income=<=50K
# IF relationship==Not-in-family AND occupation==Sales AND education==12th THEN income=<=50K
# IF relationship==Not-in-family AND occupation==Sales AND education==Assoc-acdm THEN income=<=50K
# IF relationship==Not-in-family AND occupation==Other-service AND education!=Bachelors THEN income=<=50K
# IF education==Doctorate AND workclass==Local-gov THEN income=<=50K
# IF education==Doctorate AND workclass==Self-emp-inc THEN income=>50K
# IF age<=34.0 AND education==7th-8th THEN income=<=50K
# IF age<=34.0 AND education==11th THEN income=<=50K
# IF age<=34.0 AND relationship==Other-relative THEN income=>50K
# IF age<=34.0 AND race==Other THEN income=<=50K
# IF age<=34.0 AND capital-gain>=4386.0 THEN income=>50K
# IF capital-gain>=3137.0 AND workclass==Federal-gov THEN income=<=50K
# IF capital-gain>=3137.0 AND workclass==Local-gov THEN income=<=50K
# IF capital-gain>=3137.0 AND final-weight>=174525.0 THEN income=<=50K
# IF native-country==Columbia THEN income=>50K
# IF age<=34.0 AND capital-gain>=3103.0 THEN income=>50K
# IF age<=34.0 AND native-country==Greece THEN income=<=50K
# IF age<=34.0 AND native-country==Philippines THEN income=<=50K
# IF marital-status==Never-married AND native-country==Philippines THEN income=>50K
# IF relationship==Not-in-family AND race==Asian-Pac-Islander THEN income=<=50K
# IF marital-status==Never-married AND race==Asian-Pac-Islander THEN income=>50K
# IF relationship==Unmarried AND workclass==State-gov THEN income=<=50K
# IF relationship==Not-in-family AND occupation==Sales AND education==Assoc-voc THEN income=<=50K
# IF marital-status==Divorced AND occupation==Transport-moving AND final-weight>=123703.0 THEN income=<=50K
# IF marital-status==Divorced AND occupation==Transport-moving THEN income=>50K
# IF relationship==Not-in-family AND occupation==Sales AND education==Masters THEN income=<=50K
# IF marital-status==Never-married AND education==Some-college AND workclass==State-gov THEN income=<=50K
# IF marital-status==Never-married AND education==HS-grad AND workclass==Local-gov THEN income=<=50K
# IF marital-status==Never-married AND education==HS-grad AND workclass==State-gov THEN income=<=50K
# IF relationship==Not-in-family AND occupation==Sales AND race==Black THEN income=<=50K
# IF occupation==Machine-op-inspct AND race==Black AND relationship!=Husband THEN income=<=50K
# IF marital-status==Never-married AND age<=30.0 AND workclass==Local-gov THEN income=<=50K
# IF marital-status==Never-married AND education==HS-grad AND occupation==Exec-managerial THEN income=<=50K
# IF relationship==Unmarried AND education==HS-grad AND occupation==Prof-specialty THEN income=<=50K
# IF marital-status==Never-married AND education==Some-college AND occupation==Adm-clerical THEN income=>50K
# IF relationship==Unmarried AND occupation==Adm-clerical THEN income=<=50K
# IF marital-status==Never-married AND education==Some-college AND occupation==Tech-support THEN income=<=50K
# IF occupation==Farming-fishing AND workclass==Self-emp-inc THEN income=<=50K
# IF occupation==Other-service AND race==Asian-Pac-Islander THEN income=>50K
# IF occupation==Other-service AND hour-per-week>=45.0 THEN income=>50K
# IF marital-status==Divorced AND occupation==Other-service THEN income=<=50K
# IF marital-status==Never-married AND education==Some-college AND occupation==Transport-moving THEN income=<=50K
# IF relationship==Unmarried AND education==Some-college AND workclass==Federal-gov THEN income=<=50K
# IF marital-status==Divorced AND race==Asian-Pac-Islander THEN income=>50K
# IF relationship==Unmarried AND workclass==Federal-gov THEN income=>50K
# IF relationship==Unmarried AND education==Assoc-acdm THEN income=<=50K
# IF marital-status==Never-married AND education==Some-college AND race==Black THEN income=<=50K
# IF marital-status==Never-married AND final-weight>=467108.0 THEN income=>50K
# IF marital-status==Never-married AND education==Some-college AND occupation==Prof-specialty THEN income=<=50K
# IF marital-status==Never-married AND education==Some-college AND sex==Female THEN income=<=50K
# IF marital-status==Never-married AND occupation==Protective-serv THEN income=>50K
# IF education==Doctorate AND occupation==Craft-repair THEN income=<=50K
# IF education==Doctorate AND age>=41.0 THEN income=>50K
# IF relationship==Unmarried AND education==Doctorate THEN income=<=50K
# IF age>=63.0 AND workclass==Local-gov THEN income=<=50K
# IF marital-status==Divorced AND occupation==Sales AND workclass==Self-emp-inc THEN income=>50K
# IF relationship==Unmarried AND workclass==Self-emp-inc THEN income=<=50K
# IF marital-status==Divorced AND occupation==Sales AND age>=39.0 THEN income=<=50K
# IF relationship==Unmarried AND education==HS-grad AND occupation!=Exec-managerial THEN income=<=50K
# IF relationship==Unmarried AND education==HS-grad AND race==Black THEN income=>50K
# IF relationship==Unmarried AND education==HS-grad THEN income=<=50K
# IF relationship==Unmarried AND race==Black THEN income=<=50K
# IF marital-status==Divorced AND workclass==State-gov AND education==Assoc-acdm THEN income=<=50K
# IF occupation==Machine-op-inspct AND final-weight>=211678.0 AND workclass!=Private THEN income=<=50K
# IF occupation==Machine-op-inspct AND workclass==Self-emp-inc THEN income=>50K
# IF education==7th-8th AND workclass==Self-emp-inc THEN income=>50K
# IF education==7th-8th AND occupation==Handlers-cleaners THEN income=<=50K
# IF education==7th-8th AND occupation==Protective-serv THEN income=<=50K
# IF education==7th-8th AND race==Amer-Indian-Eskimo THEN income=<=50K
# IF marital-status==Never-married AND education==HS-grad AND occupation==Tech-support THEN income=<=50K
# IF education==7th-8th AND race==Black THEN income=>50K
# IF education==7th-8th AND final-weight>=259532.0 THEN income=<=50K
# IF capital-loos>=1848.0 AND age>=36.0 AND workclass==State-gov THEN income=>50K
# IF capital-loos>=1848.0 AND workclass==State-gov THEN income=<=50K
# IF capital-loos>=1848.0 AND education==HS-grad AND workclass==Local-gov THEN income=<=50K
# IF capital-loos>=1848.0 AND education==HS-grad THEN income=>50K
# IF capital-loos>=1887.0 AND occupation==Transport-moving THEN income=<=50K
# IF capital-loos>=1887.0 AND age>=39.0 THEN income=>50K
# ...
# IF final-weight<=187720.0 AND workclass==Local-gov THEN income=<=50K
# IF final-weight<=186556.0 AND final-weight>=186556.0 THEN income=>50K
# IF final-weight<=187720.0 AND workclass==Self-emp-inc THEN income=>50K
# IF workclass==Self-emp-inc THEN income=<=50K
# IF final-weight<=188069.0 AND final-weight>=188069.0 THEN income=>50K
# IF final-weight<=188330.0 AND final-weight>=188330.0 THEN income=>50K
# IF final-weight<=188615.0 AND final-weight>=188615.0 THEN income=>50K
# IF final-weight<=189680.0 AND final-weight>=189680.0 THEN income=>50K
# IF final-weight<=190290.0 AND final-weight>=190290.0 THEN income=>50K
# IF final-weight<=190511.0 AND final-weight>=190511.0 THEN income=>50K
# IF final-weight<=190759.0 AND final-weight>=190759.0 THEN income=>50K
# IF final-weight<=190909.0 AND final-weight>=190909.0 THEN income=>50K
# IF final-weight<=191161.0 AND workclass==Local-gov THEN income=>50K
# IF final-weight<=191256.0 AND final-weight>=191256.0 THEN income=>50K
# IF occupation==Transport-moving AND hour-per-week>=65.0 THEN income=<=50K
# IF education==HS-grad AND hour-per-week>=65.0 THEN income=>50K
# IF final-weight<=191277.0 AND final-weight>=191277.0 THEN income=>50K
# IF final-weight<=192053.0 AND occupation==Protective-serv THEN income=>50K
# IF final-weight<=192053.0 AND race==Black THEN income=<=50K
# IF age<=39.0 AND education==Assoc-voc THEN income=<=50K
# IF education==Assoc-voc THEN income=>50K
# IF age<=39.0 AND relationship!=Husband THEN income=<=50K
# IF occupation==Protective-serv AND workclass!=Local-gov THEN income=<=50K
# IF occupation==Sales AND hour-per-week>=65.0 THEN income=>50K
# IF final-weight<=192053.0 AND final-weight>=187454.0 AND workclass!=Private THEN income=<=50K
# IF final-weight<=185325.0 AND final-weight>=185325.0 THEN income=>50K
# IF final-weight<=192053.0 AND final-weight>=192053.0 THEN income=>50K
# IF final-weight<=192323.0 AND workclass==Local-gov THEN income=>50K
# IF occupation==Protective-serv AND education==Some-college THEN income=<=50K
# IF final-weight<=201732.0 AND workclass==Local-gov THEN income=>50K
# IF age<=39.0 AND workclass==Local-gov AND age>=35.0 THEN income=<=50K
# IF occupation==Protective-serv AND age>=49.0 THEN income=>50K
# IF education==HS-grad AND occupation==Protective-serv THEN income=<=50K
# IF age<=39.0 AND occupation==Protective-serv THEN income=>50K
# IF occupation==Protective-serv THEN income=<=50K
# IF age<=39.0 AND workclass==Local-gov THEN income=<=50K
# IF education==HS-grad AND workclass==Local-gov THEN income=>50K
# IF occupation==Craft-repair AND workclass==Local-gov THEN income=>50K
# IF workclass==Local-gov THEN income=<=50K
# IF occupation==Transport-moving AND age>=48.0 AND final-weight>=234213.0 THEN income=<=50K
# IF occupation==Transport-moving AND age>=48.0 THEN income=>50K
# IF occupation==Transport-moving AND education==Bachelors THEN income=<=50K
# IF occupation==Transport-moving AND hour-per-week>=50.0 THEN income=<=50K
# IF education==HS-grad AND hour-per-week>=60.0 AND workclass!=Private THEN income=<=50K
# IF final-weight<=201732.0 AND occupation==Transport-moving AND final-weight>=112271.0 THEN income=<=50K
# IF final-weight<=201732.0 AND occupation==Transport-moving THEN income=>50K
# IF age<=39.0 AND occupation==Transport-moving THEN income=>50K
# IF occupation==Transport-moving AND hour-per-week>=45.0 THEN income=<=50K
# IF age<=39.0 AND race==Black AND education==HS-grad THEN income=<=50K
# IF hour-per-week>=44.0 AND age>=62.0 THEN income=>50K
# IF age>=64.0 THEN income=<=50K
# IF age<=39.0 AND final-weight<=108116.0 AND final-weight>=108116.0 THEN income=>50K
# IF age<=39.0 AND final-weight<=110713.0 AND final-weight>=110713.0 THEN income=>50K
# IF age<=39.0 AND final-weight<=111363.0 AND workclass!=Private THEN income=<=50K
# IF age<=39.0 AND final-weight<=111363.0 AND final-weight>=111363.0 THEN income=>50K
# IF age<=39.0 AND final-weight<=112115.0 AND workclass!=Private THEN income=<=50K
# IF age<=39.0 AND final-weight<=112115.0 AND final-weight>=112115.0 THEN income=>50K
# IF age<=39.0 AND final-weight<=112561.0 AND final-weight>=112561.0 THEN income=>50K
# IF age<=39.0 AND final-weight<=114224.0 AND final-weight>=114224.0 THEN income=>50K
# IF age<=39.0 AND final-weight<=129624.0 AND workclass!=Private THEN income=<=50K
# IF age<=39.0 AND final-weight<=119432.0 AND final-weight>=119432.0 THEN income=>50K
# IF age<=39.0 AND final-weight<=129624.0 AND final-weight>=129624.0 THEN income=>50K
# IF age<=31.0 AND workclass!=Private THEN income=>50K
# IF age<=31.0 AND final-weight>=231263.0 THEN income=<=50K
# IF age<=39.0 AND final-weight<=130057.0 AND final-weight>=130057.0 THEN income=>50K
# IF age<=39.0 AND final-weight<=132879.0 AND final-weight>=132879.0 THEN income=>50K
# IF age<=39.0 AND final-weight<=140752.0 AND workclass!=Private THEN income=>50K
# IF age<=39.0 AND final-weight<=149726.0 AND final-weight>=149726.0 THEN income=>50K
# IF age<=39.0 AND final-weight<=153976.0 AND final-weight>=153976.0 THEN income=>50K
# IF age<=39.0 AND final-weight<=154227.0 AND final-weight>=154227.0 THEN income=>50K
# IF age<=39.0 AND final-weight<=163237.0 AND final-weight>=163237.0 THEN income=>50K
# IF education==HS-grad AND occupation==Sales AND workclass!=Private THEN income=<=50K
# IF final-weight<=168538.0 AND final-weight>=168538.0 THEN income=>50K
# IF final-weight<=171216.0 AND final-weight>=171216.0 THEN income=>50K
# IF final-weight<=174789.0 AND final-weight>=174789.0 THEN income=>50K
# IF education==HS-grad AND occupation==Sales AND hour-per-week>=49.0 THEN income=<=50K
# IF final-weight>=201732.0 AND relationship!=Husband THEN income=<=50K
# IF final-weight>=201732.0 AND final-weight<=204046.0 AND final-weight>=204046.0 THEN income=<=50K
# IF final-weight>=201732.0 AND final-weight<=204527.0 AND final-weight>=204527.0 THEN income=<=50K
# IF final-weight>=201732.0 AND final-weight<=206051.0 AND age>=34.0 THEN income=>50K
# IF education==Bachelors AND race==Black THEN income=<=50K
# IF final-weight<=206964.0 AND race==Black THEN income=>50K
# IF age<=39.0 AND final-weight<=179271.0 AND workclass!=Private THEN income=<=50K
# IF final-weight<=172538.0 AND final-weight>=172538.0 THEN income=>50K
# IF age<=39.0 AND workclass!=Private THEN income=>50K
# IF final-weight<=172666.0 AND final-weight>=172666.0 THEN income=>50K
# IF age<=39.0 AND final-weight<=179271.0 AND final-weight>=179271.0 THEN income=>50K
# IF age<=39.0 AND final-weight<=192626.0 AND final-weight>=192626.0 THEN income=>50K
# IF final-weight<=206964.0 AND final-weight>=206964.0 THEN income=>50K
# IF final-weight<=207201.0 AND final-weight>=207201.0 THEN income=>50K
# IF final-weight<=207940.0 AND final-weight>=207940.0 THEN income=>50K
# IF final-weight<=211440.0 AND final-weight>=211440.0 THEN income=>50K
# IF final-weight<=211654.0 AND final-weight>=211654.0 THEN income=>50K
# IF final-weight<=211762.0 AND final-weight>=211762.0 THEN income=>50K
# IF final-weight<=212120.0 AND final-weight>=212120.0 THEN income=>50K
# IF final-weight<=212465.0 AND final-weight>=212465.0 THEN income=>50K
# IF final-weight<=212960.0 AND final-weight>=212960.0 THEN income=>50K
# IF final-weight<=223327.0 AND final-weight>=223327.0 THEN income=>50K
# IF final-weight<=224207.0 AND final-weight>=224207.0 THEN income=>50K
# IF final-weight<=225456.0 AND final-weight>=225456.0 THEN income=>50K
# IF final-weight<=226443.0 AND final-weight>=226443.0 THEN income=>50K
# IF final-weight<=226902.0 AND final-weight>=226902.0 THEN income=>50K
# IF final-weight<=227545.0 AND final-weight>=227545.0 THEN income=>50K
# IF final-weight<=231043.0 AND final-weight>=231043.0 THEN income=>50K
# IF final-weight<=231689.0 AND final-weight>=231689.0 THEN income=>50K
# IF final-weight<=174283.0 AND final-weight>=174283.0 THEN income=>50K
# IF final-weight<=232618.0 AND final-weight>=232618.0 THEN income=>50K
# IF final-weight<=233130.0 AND final-weight>=233130.0 THEN income=>50K
# IF final-weight<=235786.0 AND final-weight>=235786.0 THEN income=>50K
# IF final-weight<=236852.0 AND final-weight>=236852.0 THEN income=>50K
# IF final-weight<=238162.0 AND final-weight>=238162.0 THEN income=>50K
# IF final-weight<=238415.0 AND final-weight>=238415.0 THEN income=>50K
# IF final-weight<=240124.0 AND final-weight>=240124.0 THEN income=>50K
# IF final-weight<=243580.0 AND occupation==Transport-moving THEN income=<=50K
# IF final-weight<=243580.0 AND final-weight>=243580.0 THEN income=>50K
# IF final-weight<=271828.0 AND final-weight>=271828.0 THEN income=>50K
# IF final-weight<=283037.0 AND final-weight>=283037.0 THEN income=>50K
# IF education==Some-college AND final-weight>=353808.0 THEN income=>50K
# IF final-weight<=175339.0 AND final-weight>=175339.0 THEN income=>50K
# IF final-weight<=179668.0 AND final-weight>=179668.0 THEN income=>50K
# IF education==Some-college AND hour-per-week>=60.0 THEN income=<=50K
# IF final-weight<=185385.0 AND final-weight>=185385.0 THEN income=>50K
# IF final-weight<=186809.0 AND final-weight>=186809.0 THEN income=>50K
# IF final-weight<=187322.0 AND final-weight>=187322.0 THEN income=>50K
# IF final-weight<=192360.0 AND final-weight>=192360.0 THEN income=>50K
# IF final-weight<=245062.0 AND final-weight>=245062.0 THEN income=>50K
# IF occupation!=Prof-specialty AND final-weight>=510072.0 THEN income=>50K
# IF occupation!=Prof-specialty AND final-weight>=386397.0 THEN income=<=50K
# IF final-weight<=303637.0 AND final-weight>=303637.0 THEN income=>50K
# IF final-weight<=305597.0 AND final-weight>=305597.0 THEN income=>50K
# IF occupation!=Prof-specialty AND final-weight>=379522.0 THEN income=>50K
# IF final-weight>=373050.0 THEN income=<=50K
# IF final-weight>=354078.0 THEN income=>50K
# IF final-weight>=349028.0 THEN income=<=50K
# IF final-weight>=343721.0 THEN income=>50K
# IF final-weight>=337825.0 THEN income=<=50K
# IF final-weight>=308691.0 AND education==Bachelors THEN income=>50K
# IF final-weight>=336595.0 THEN income=>50K
# IF final-weight<=192381.0 AND final-weight>=192381.0 THEN income=>50K
# IF occupation==Prof-specialty AND hour-per-week>=60.0 THEN income=>50K
# IF education==HS-grad AND age<=42.0 AND workclass!=Private THEN income=<=50K
# IF education==HS-grad AND age<=40.0 AND final-weight>=334291.0 THEN income=>50K
# IF final-weight>=332355.0 THEN income=<=50K
# IF final-weight>=328216.0 THEN income=>50K
# IF final-weight>=319733.0 THEN income=<=50K
# IF final-weight>=310632.0 THEN income=>50K
# IF final-weight>=298885.0 THEN income=<=50K
# IF final-weight>=297449.0 THEN income=>50K
# IF final-weight>=290560.0 THEN income=<=50K
# IF final-weight>=287548.0 THEN income=>50K
# IF race==Black AND workclass!=Private THEN income=<=50K
# IF education==HS-grad AND final-weight>=247752.0 THEN income=<=50K
# IF final-weight>=264052.0 AND age>=39.0 THEN income=>50K
# IF final-weight>=261382.0 THEN income=<=50K
# IF education==HS-grad AND final-weight>=247019.0 THEN income=>50K
# IF race==Black THEN income=<=50K
# IF occupation==Craft-repair AND final-weight>=254211.0 THEN income=>50K
# IF final-weight>=259323.0 THEN income=>50K
# IF final-weight>=224799.0 AND workclass!=Private THEN income=<=50K
# IF final-weight>=224799.0 AND education==Bachelors THEN income=<=50K
# IF occupation!=Exec-managerial AND final-weight>=225193.0 THEN income=<=50K
# IF final-weight>=224232.0 THEN income=>50K
# IF education==HS-grad AND age<=40.0 AND occupation==Sales THEN income=<=50K
# IF hour-per-week<=44.0 AND hour-per-week>=44.0 THEN income=>50K
# IF age<=42.0 AND education==HS-grad AND occupation==Sales THEN income=<=50K
# IF age<=42.0 AND age>=42.0 AND workclass!=Self-emp-not-inc THEN income=>50K
# IF occupation==Prof-specialty AND final-weight>=185291.0 THEN income=<=50K
# IF occupation==Prof-specialty AND final-weight>=180985.0 THEN income=>50K
# IF occupation==Prof-specialty AND education==Bachelors THEN income=<=50K
# IF final-weight<=193026.0 AND final-weight>=193026.0 THEN income=>50K
# IF education==HS-grad AND final-weight>=155434.0 AND workclass!=Private THEN income=<=50K
# IF education==HS-grad AND workclass!=Private THEN income=>50K
# IF education==HS-grad AND final-weight>=155434.0 AND relationship!=Husband THEN income=<=50K
# IF age<=44.0 AND education==HS-grad AND relationship!=Husband THEN income=>50K
# IF age<=44.0 AND relationship!=Husband THEN income=<=50K
# IF relationship!=Husband AND final-weight>=142828.0 THEN income=>50K
# IF relationship!=Husband THEN income=<=50K
# IF hour-per-week<=45.0 AND education==HS-grad AND occupation==Sales THEN income=<=50K
# IF final-weight<=193720.0 AND final-weight>=181382.0 AND workclass!=Private THEN income=<=50K
# IF final-weight<=193720.0 AND final-weight>=181382.0 AND final-weight>=193720.0 THEN income=>50K
# IF final-weight<=213841.0 AND final-weight>=213841.0 THEN income=>50K
# IF final-weight<=215310.0 AND final-weight>=215310.0 THEN income=>50K
# IF occupation==Craft-repair AND hour-per-week>=56.0 THEN income=>50K
# IF final-weight>=220511.0 THEN income=<=50K
# IF final-weight>=217460.0 THEN income=>50K
# IF final-weight>=209040.0 THEN income=<=50K
# IF final-weight>=208043.0 THEN income=>50K
# IF occupation==Craft-repair AND final-weight>=199378.0 THEN income=<=50K
# IF final-weight>=198692.0 AND workclass==Private THEN income=>50K
# IF age<=42.0 AND occupation==Prof-specialty THEN income=>50K
# IF occupation==Craft-repair AND final-weight>=198692.0 THEN income=>50K
# IF final-weight>=197702.0 THEN income=<=50K
# IF final-weight>=196266.0 THEN income=>50K
# IF occupation==Craft-repair AND workclass!=Private THEN income=<=50K
# IF workclass!=Private AND final-weight>=44728.0 THEN income=>50K
# IF workclass!=Private THEN income=<=50K
# IF age<=44.0 AND occupation==Prof-specialty THEN income=<=50K
# IF occupation==Craft-repair AND final-weight>=180342.0 THEN income=<=50K
# IF final-weight>=193882.0 AND age>=44.0 THEN income=>50K
# IF occupation==Craft-repair AND final-weight>=177368.0 THEN income=>50K
# IF occupation==Craft-repair AND final-weight>=170769.0 THEN income=<=50K
# IF occupation==Craft-repair AND final-weight>=169397.0 THEN income=>50K
# IF age<=44.0 AND education==Some-college AND age>=38.0 THEN income=<=50K
# IF final-weight>=193882.0 THEN income=>50K
# IF final-weight>=185099.0 THEN income=<=50K
# IF final-weight>=121441.0 AND occupation==Prof-specialty THEN income=<=50K
# IF age<=44.0 AND education==HS-grad AND age>=33.0 THEN income=<=50K
# IF occupation==Craft-repair AND final-weight>=166124.0 THEN income=>50K
# IF occupation!=Exec-managerial AND final-weight>=165152.0 THEN income=>50K
# IF final-weight>=176101.0 THEN income=<=50K
# IF final-weight>=170562.0 THEN income=>50K
# IF education==Some-college AND final-weight>=133403.0 THEN income=<=50K
# IF final-weight>=164197.0 THEN income=>50K
# IF final-weight>=162572.0 THEN income=<=50K
# IF final-weight>=160785.0 THEN income=>50K
# IF final-weight>=155434.0 AND age>=47.0 THEN income=<=50K
# IF occupation==Sales AND final-weight>=101593.0 THEN income=<=50K
# IF final-weight>=147098.0 THEN income=>50K
# IF final-weight>=138192.0 THEN income=<=50K
# IF final-weight>=128143.0 THEN income=>50K
# IF final-weight>=122116.0 THEN income=<=50K
# IF final-weight>=112821.0 AND education==Bachelors THEN income=>50K
# IF hour-per-week>=45.0 AND education==Bachelors THEN income=>50K
# IF final-weight>=112821.0 AND age>=58.0 THEN income=>50K
# IF occupation==Prof-specialty THEN income=<=50K
# IF occupation==Craft-repair AND final-weight>=108993.0 THEN income=>50K
# IF hour-per-week>=60.0 THEN income=<=50K
# IF final-weight>=112840.0 THEN income=>50K
# IF final-weight>=106255.0 THEN income=<=50K
# IF final-weight>=104440.0 THEN income=>50K
# IF final-weight>=102147.0 THEN income=<=50K
# IF final-weight>=98791.0 THEN income=>50K
# IF hour-per-week>=55.0 THEN income=<=50K
# IF final-weight>=50223.0 AND age>=59.0 THEN income=<=50K
# IF age>=54.0 THEN income=>50K
# IF age>=50.0 THEN income=<=50K
# IF occupation==Sales THEN income=<=50K
# IF occupation==Craft-repair AND age>=46.0 THEN income=<=50K
# IF age>=44.0 THEN income=>50K
# IF age>=36.0 THEN income=<=50K
# IF age<=32.0 THEN income=>50K
# IF TRUE THEN income=<=50K

# %%
# fazendo previsões
previsoes = Orange.evaluation.testing.TestOnTestData(base_treinamento, base_teste, [lambda testdata: regras_census])

# %%
previsoes

# %%
# Calculando precisão do modelo
Orange.evaluation.CA(previsoes)
# Out:
# array([0.8])

# %% [markdown]
# # Classificador base - Majority learner

# %%
import Orange

# %%
# carregando dados
base_census = Orange.data.Table('../datasets/census_regras.csv')

# %%
base_census.domain
# Out:
# [age, workclass, final-weight, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loos, hour-per-week, native-country | income]

# %%
# fazendo treinamento
majority = Orange.classification.MajorityLearner()

# %%
# fazendo previsões
previsoes = Orange.evaluation.testing.TestOnTestData(base_census, base_census, [majority])

# %%
# calculando precisão
Orange.evaluation.CA(previsoes)
# Out:
# array([0.75919044])

# %%
# exibindo a classe dos registors
for registro in base_census:
    print(registro.get_class())
# Out:
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# ...
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# >50K

# %%
# contagem das classes
from collections import Counter
Counter(str(registro.get_class()) for registro in base_census)
# Out:
# Counter({'<=50K': 24720, '>50K': 7841})

# %%
# divindo a numero de registros da classe majoritaria pelo número total de registros, teremos a precisão
24720 / (24720 + 7841)
# Out:
# 0.7591904425539756

# %% [markdown]
# # Aprendizado baseado em instâncias - KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
#carregando dados processados
import pickle

with open('../datasets/processed/census.pkl', 'rb') as f:
    X_census_treinamento, Y_census_treinamento, X_census_teste, Y_census_teste = pickle.load(f)

# %%
X_census_treinamento.shape, Y_census_treinamento.shape
# Out:
# ((27676, 108), (27676,))

# %%
X_census_teste.shape, Y_census_teste.shape
# Out:
# ((4885, 108), (4885,))

# %%
knn_census = KNeighborsClassifier(n_neighbors=5)
knn_census.fit(X_census_treinamento, Y_census_treinamento)
# Out:
# KNeighborsClassifier()

# %%
# gerando e visualizando previões
previsoes = knn_census.predict(X_census_teste)
previsoes
# Out:
# array([' <=50K', ' <=50K', ' >50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       shape=(4885,), dtype=object)

# %%
Y_census_teste
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' <=50K'],
#       shape=(4885,), dtype=object)

# %%
# gerando métricas
from sklearn.metrics import accuracy_score, classification_report
accuracy_score(Y_census_teste, previsoes)
# Out:
# 0.8223132036847492

# %%
from yellowbrick.classifier import ConfusionMatrix
cm = ConfusionMatrix(knn_census)
cm.fit(X_census_treinamento, Y_census_treinamento)
cm.score(X_census_teste, Y_census_teste)
# Out:
# 0.8223132036847492

# %%
print(classification_report(Y_census_teste, previsoes))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.87      0.90      0.88      3693
#         >50K       0.66      0.57      0.61      1192
#
#     accuracy                           0.82      4885
#    macro avg       0.76      0.74      0.75      4885
# weighted avg       0.82      0.82      0.82      4885

# %% [markdown]
# # Reegressão logística

# %%
import pickle
import numpy as np
from sklearn.linear_model import LogisticRegression

# %%
# carregando dados processados
with open('../datasets/processed/census.pkl', 'rb') as f:
    X_census_treinamento, Y_census_treinamento, X_census_teste, Y_census_teste = pickle.load(f)

# %%
X_census_treinamento.shape, Y_census_treinamento.shape
# Out:
# ((27676, 108), (27676,))

# %%
X_census_teste.shape, Y_census_teste.shape
# Out:
# ((4885, 108), (4885,))

# %%
# fazendo treinamento
logistic_census = LogisticRegression(random_state=1)
logistic_census.fit(X_census_treinamento, Y_census_treinamento)
# Out:
# LogisticRegression(random_state=1)

# %%
# parametro b0
logistic_census.intercept_
# Out:
# array([-2.10552416])

# %%
# coeficientes (um valor para cada um dos atributos previsores)
logistic_census.coef_
# Out:
# array([[-6.98488613e-02,  1.18355815e-01, -9.28364487e-03,
#         -6.32571637e-02,  5.70026706e-02,  5.07381719e-02,
#         -8.84284931e-02, -5.02268816e-02, -1.24694668e-01,
#         -1.02481824e-01, -1.17822786e-01, -3.66227818e-02,
#         -1.89874033e-02, -2.67960548e-02, -8.22889018e-02,
#         -7.88822810e-02, -8.12332696e-03,  1.13390793e-02,
#          1.45986267e-01,  1.18924828e-01, -7.54038219e-02,
#          1.44347173e-01, -5.54400102e-01,  1.13453107e-01,
#          2.46279059e-02, -1.90450912e-01,  4.34375255e-02,
#          7.00139994e-01, -6.46427239e-02, -5.18599668e-01,
#         -1.07259785e-01, -8.85445200e-02, -7.37373311e-02,
#         -1.37206225e-02, -2.06416506e-02,  2.26862374e-02,
#          2.52008753e-01, -1.67994077e-01, -1.41452274e-01,
#         -8.40072161e-02, -2.57017139e-01, -2.82516289e-01,
#          1.61879470e-01,  8.58540408e-02,  8.36697148e-02,
#          1.09051852e-01, -2.53383593e-02, -2.30592713e-02,
#          1.32752101e-01, -8.29001225e-02, -3.09430677e-01,
#          5.43021241e-02,  2.94707729e-01, -5.22254983e-02,
#          2.29932006e-02, -2.37243274e-02, -8.61337297e-03,
#          2.49637102e-02, -2.09286316e-01,  2.09286316e-01,
#         -1.84243639e-02,  3.69770224e-02,  2.40783987e-02,
#         -3.36135415e-02, -1.02150610e-01,  2.12974056e-02,
#         -7.14306234e-02, -8.58383888e-03, -2.88674939e-02,
#          4.66080098e-04,  1.29162299e-02,  1.24362959e-02,
#         -3.07437358e-02, -6.79394757e-03, -8.69907386e-04,
#         -2.08051435e-02, -1.97773321e-02,  1.09596926e-02,
#         -3.33453921e-03, -1.49777979e-02, -2.04848418e-03,
#          8.66344938e-03,  4.13984276e-02,  2.12866208e-03,
#          1.66880724e-02, -3.02036961e-03, -6.43684515e-02,
#         -5.13522058e-03, -1.12991656e-01, -1.44752791e-02,
#          6.55580046e-02,  5.68173131e-03, -8.86988978e-04,
#         -4.43366968e-02,  6.14715351e-03, -4.47212506e-02,
#          4.29417992e-03, -7.56485673e-03, -2.97178091e-02,
#          7.37532932e-02, -5.23867514e-02,  1.22472161e-02,
#          3.42030703e-01,  6.91858361e-02,  3.76517436e-01,
#          2.34494690e+00,  2.52864190e-01,  3.73152936e-01]])

# %%
previsoes  = logistic_census.predict(X_census_teste)
previsoes
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       shape=(4885,), dtype=object)

# %%
Y_census_teste
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' <=50K'],
#       shape=(4885,), dtype=object)

# %%
# gerando métricas
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from yellowbrick.classifier import ConfusionMatrix

# %%
accuracy_score(Y_census_teste, previsoes)
# Out:
# 0.8497441146366428

# %%
confusion_matrix(Y_census_teste, previsoes)
# Out:
# array([[3424,  269],
#        [ 465,  727]])

# %%
cm = ConfusionMatrix(logistic_census)
cm.fit(X_census_treinamento, Y_census_treinamento)
cm.score(X_census_teste, Y_census_teste)
# Out:
# 0.8497441146366428

# %%
print(classification_report(Y_census_teste, previsoes))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.88      0.93      0.90      3693
#         >50K       0.73      0.61      0.66      1192
#
#     accuracy                           0.85      4885
#    macro avg       0.81      0.77      0.78      4885
# weighted avg       0.84      0.85      0.84      4885
